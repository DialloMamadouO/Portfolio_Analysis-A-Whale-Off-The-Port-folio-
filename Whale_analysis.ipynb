# %%
# Import Libraries and Dependencies
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
# Reading Whale Returns CSV

# %%
# Read the whale returns portfolio and clean the data
whale_returns_csv = Path("whale_returns.csv")
whale_returns_df = pd.read_csv(whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Let's Determine the number of nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Let's Drop Null Values
whale_returns_df.dropna(inplace=True)
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %%
# Let's determine the number of remaining nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Algorithmic Daily Returns

# Read the Algorithmic daily returns and clean the data

# %%
# Algorithmic daily returns
algo_returns_csv = Path("algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)

algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Let's count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Let's drop null values 
algo_returns_df.dropna(inplace=True)
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
# Let's count remaining null values 
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# S&P500 Returns

# Read The S&P500 Historic Closing Prices and Create a New Daily Returns
# DataFrame from the Data

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("sp500_history.csv")
sp500_history_df = pd.read_csv(sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_history_df = sp500_history_df.sort_index()
sp500_history_df.head(5)
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Type
# Let's remove dollar signs from the closing prices
sp500_history_df['Close'] = sp500_history_df['Close'].str.replace("$", "")
sp500_history_df.head()
sp500_history_df['Close'] = sp500_history_df['Close'].astype(float)

# %%
sp500_history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_returns_df = sp500_history_df.pct_change()
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop Nulls
sp500_returns_df.dropna(inplace=True)
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column

# %%
sp500_returns_df.rename(columns = {"Close":"S&P 500"}, inplace = True)
sp500_returns_df
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Combine Whale, Algorithmic, and S&P500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat([whale_returns_df, algo_returns_df, sp500_returns_df], axis="columns", join="inner")
# Sort datetime index in ascending order (past to present)
combined_df.sort_index(inplace=True)

combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %%
# Portfolio Analysis

# In this Section I will Calculate and Visualize Performance and Risk Metrics for this Portfolio

# %%
# Performance

# Let's Calculate and Plot the daily returns and cumulative returns.
# Does any portfolio outperfom the S&P 500?

# %%
# Let's plot daily returns
combined_df.plot(figsize=(20, 10), title='Daily Returns')

# %%
# Let's calculate and plot cumulative returns 
cumulative_returns = (1 + combined_df).cumprod() 
cumulative_returns.plot(figsize=(20,10), title='Cumulative Returns')

# %%
# Risk

# %%
#Determine the risk of each portfolio:
    
#Create a box plot for each portfolio. 
#Calculate the standard deviation for all portfolios
#Determine which portfolios are riskier than the S&P 500
#Calculate the Annualized Standard Deviation

combined_df.plot(kind= "box", figsize= (20, 10), title='Portfolio Risk')

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?

# %%
# Standard deviation of portfolios
volatility = combined_df.std()
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Determine which portfolios are riskier than the sp500

# %%
volatility > volatility['S&P 500']
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
# Calculate the anualysed standard deviation 252 trading days

# %%
volatility = combined_df.std()*np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# PAULSON & CO.INC.              0.111488
# Algo 1                         0.120967
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 2                         0.132430
# S&P 500                        0.135786
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# dtype: float64

# %%
# Rolling Statistics

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
combined_df.rolling(window=21).std().plot(figsize=(20, 10), title='21 Day Rolling Standard Deviation')

# %%
# Construct a correlation table

# %%
correlation = combined_df.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.837864
# PAULSON & CO.INC.            0.669732
# TIGER GLOBAL MANAGEMENT LLC  0.623946
# BERKSHIRE HATHAWAY INC       0.751371
# Algo 1                       0.279494
# Algo 2                       0.858764
# S&P 500                      1.000000

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# Beta = covariance/variance

# %%
# Calculate Covariance for Berkshire Hathaway Inc vs S&P 500

# %%
covariance = whale_returns_df['BERKSHIRE HATHAWAY INC'].cov(sp500_returns_df['S&P 500'])
covariance
# Out:
# 8.302834941861689e-05

# %%
# Calculate Variance for Berkshire Hathaway Inc

# %%
variance = whale_returns_df['BERKSHIRE HATHAWAY INC'].var()
variance
# Out:
# 0.0001646285942990748

# %%
Berkshire_Roll = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(sp500_returns_df['S&P 500'])/sp500_returns_df['S&P 500'].rolling(window=21).var()
Berkshire_Roll.dropna(inplace=True)
Berkshire_Roll.plot(figsize=(20, 10), title='BERKSHIRE HATHAWAY INC BETA')

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
combined_df.ewm(halflife=21).mean().plot(figsize=(20, 10), title='Exponentially Weighted Average')

# %%
# SHARPE RATIO

# %%
1. # Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
2. # Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios
# Out:
# 2.0

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratio = (combined_df.mean()*252)/(combined_df.std()*np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot.bar(title="Sharpe Ratios")

# %%
#On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:
#Based on this metric our algo 1 strategies outperformed both 'the market' and the whales 
#however our algo 2 strategies did not outperform all of them.

# %%
# Portfolio Returns

# %%
# Read Bestbuy Data

# %%
bby_csv_path = Path("../Resources/Bestbuy Closing Prices.csv")
bby_history_df = pd.read_csv(bby_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
bby_history_df.head()
# Out:
#             Close
# Date
# 2012-01-03  23.68
# 2012-01-04  23.23
# 2012-01-05  23.44
# 2012-01-06  24.22
# 2012-01-09  24.62

# %%
bby_history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate daily returns
bby_daily_returns = bby_history_df.pct_change()
bby_daily_returns
# Out:
#                Close
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2011 rows x 1 columns]

# %%
# Drop Nulls
bby_daily_returns.dropna(inplace=True)
bby_daily_returns.head()
# Out:
#                Close
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062

# %%
# Rename Column
bby_daily_returns.rename(columns = {"Close":"BBY"}, inplace = True)
bby_daily_returns
# Out:
#                  BBY
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2010 rows x 1 columns]

# %%
# Read Tesla Data

# %%
tsla_csv_path = Path("../Resources/Tesla Closing Prices.csv")
tsla_history_df = pd.read_csv(bby_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
tsla_history_df.head()
# Out:
#             Close
# Date
# 2012-01-03  23.68
# 2012-01-04  23.23
# 2012-01-05  23.44
# 2012-01-06  24.22
# 2012-01-09  24.62

# %%
# Check Data Types

# %%
tsla_history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate daily returns
tsla_daily_returns = tsla_history_df.pct_change()
tsla_daily_returns
# Out:
#                Close
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2011 rows x 1 columns]

# %%
# Drop Nulls
tsla_daily_returns.dropna(inplace=True)
tsla_daily_returns.head()
# Out:
#                Close
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062

# %%
tsla_daily_returns.rename(columns = {"Close":"TSLA"}, inplace = True)
tsla_daily_returns
# Out:
#                 TSLA
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2010 rows x 1 columns]

# %%
# Read Twitter Data

# %%
twtr_csv_path = Path("../Resources/Twitter Closing Prices.csv")
twtr_history_df = pd.read_csv(bby_csv_path, index_col="Date", infer_datetime_format=True, parse_dates=True)
twtr_history_df.head()
# Out:
#             Close
# Date
# 2012-01-03  23.68
# 2012-01-04  23.23
# 2012-01-05  23.44
# 2012-01-06  24.22
# 2012-01-09  24.62

# %%
# Check Data Types

# %%
twtr_history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate daily returns
twtr_daily_returns = twtr_history_df.pct_change()
twtr_daily_returns
# Out:
#                Close
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2011 rows x 1 columns]

# %%
# Drop Nulls
twtr_daily_returns.dropna(inplace=True)
twtr_daily_returns.head()
# Out:
#                Close
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062

# %%
# Rename Column
twtr_daily_returns.rename(columns = {"Close":"TWTR"}, inplace = True)
twtr_daily_returns
# Out:
#                 TWTR
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2010 rows x 1 columns]

# %%
twtr_daily_returns.dropna()
# Out:
#                 TWTR
# Date
# 2012-01-04 -0.019003
# 2012-01-05  0.009040
# 2012-01-06  0.033276
# 2012-01-09  0.016515
# 2012-01-10  0.004062
# ...              ...
# 2019-12-23 -0.001026
# 2019-12-24  0.003309
# 2019-12-26 -0.000910
# 2019-12-27 -0.009562
# 2019-12-30  0.006436
#
# [2010 rows x 1 columns]

# %%
# Concatenate all stocks into a single DataFrame
portfolio_df = pd.concat([bby_daily_returns, tsla_daily_returns, twtr_daily_returns], axis="columns", join="inner")
# Sort datetime index in ascending order (past to present)
portfolio_df.sort_index(inplace=True)
portfolio_df.head()
# Out:
#                  BBY      TSLA      TWTR
# Date
# 2012-01-04 -0.019003 -0.019003 -0.019003
# 2012-01-05  0.009040  0.009040  0.009040
# 2012-01-06  0.033276  0.033276  0.033276
# 2012-01-09  0.016515  0.016515  0.016515
# 2012-01-10  0.004062  0.004062  0.004062

# %%
# Reset index
portfolio_df.sort_index(inplace=True)
portfolio_df.head()
# Out:
#                  BBY      TSLA      TWTR
# Date
# 2012-01-04 -0.019003 -0.019003 -0.019003
# 2012-01-05  0.009040  0.009040  0.009040
# 2012-01-06  0.033276  0.033276  0.033276
# 2012-01-09  0.016515  0.016515  0.016515
# 2012-01-10  0.004062  0.004062  0.004062

# %%
# Pivot so that each column of prices represents a unique symbol
portfolio_df.head()
# Out:
#                  BBY      TSLA      TWTR
# Date
# 2012-01-04 -0.019003 -0.019003 -0.019003
# 2012-01-05  0.009040  0.009040  0.009040
# 2012-01-06  0.033276  0.033276  0.033276
# 2012-01-09  0.016515  0.016515  0.016515
# 2012-01-10  0.004062  0.004062  0.004062

# %%
# Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
portfolio_returns = portfolio_df.dot([1/3, 1/3, 1/3])
portfolio_returns.head()
# Out:
# Date
# 2012-01-04   -0.019003
# 2012-01-05    0.009040
# 2012-01-06    0.033276
# 2012-01-09    0.016515
# 2012-01-10    0.004062
# dtype: float64

# %%
portfolio_returns.dropna()
# Out:
# Date
# 2012-01-04   -0.019003
# 2012-01-05    0.009040
# 2012-01-06    0.033276
# 2012-01-09    0.016515
# 2012-01-10    0.004062
#                 ...
# 2019-12-23   -0.001026
# 2019-12-24    0.003309
# 2019-12-26   -0.000910
# 2019-12-27   -0.009562
# 2019-12-30    0.006436
# Length: 2010, dtype: float64

# %%
 # Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
joined_df = pd.concat([combined_df, portfolio_df], axis="columns", join="inner")
# Sort datetime index in ascending order (past to present)
joined_df.sort_index(inplace=True)
joined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500       BBY      TSLA      TWTR
# Date
# 2015-03-03 -0.000949 -0.004539  0.014238  0.014238  0.014238
# 2015-03-04  0.002416 -0.004389  0.015569  0.015569  0.015569
# 2015-03-05  0.004323  0.001196 -0.004021 -0.004021 -0.004021
# 2015-03-06 -0.011460 -0.014174  0.002019  0.002019  0.002019
# 2015-03-09  0.001303  0.003944  0.003022  0.003022  0.003022

# %%
#Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
volatility = joined_df.std()
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# BBY                            0.021918
# TSLA                           0.021918
# TWTR                           0.021918
# dtype: float64

# %%
volatility > volatility["S&P 500"]
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# BBY                             True
# TSLA                            True
# TWTR                            True
# dtype: bool

# %%
# Annualized Standard Deviation

# %%
volatility = joined_df.std()*np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# PAULSON & CO.INC.              0.111488
# Algo 1                         0.120967
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 2                         0.132430
# S&P 500                        0.135786
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# BBY                            0.347944
# TSLA                           0.347944
# TWTR                           0.347944
# dtype: float64

# %%
# Rolling
joined_df.rolling(window=21).std().plot(figsize=(20, 10), title='21 Day Rolling Standard Deviation')

# %%
# Annualized Sharpe Ratios
sharpe_ratio = (joined_df.mean()*252)/(joined_df.std()*np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# BBY                            0.618153
# TSLA                           0.618153
# TWTR                           0.618153
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot.bar(title="Sharpe Ratios")

# %%
# Based on this algo 1 is outperforming all of them. My custom portfolio is doing as good as algo 2 and Berkshire Hathaway Inc, but less than the S&P 500.

# %%
# Create a correlation analysis
correlation = joined_df.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
# BBY                                           0.339916            0.249937
# TSLA                                          0.339916            0.249937
# TWTR                                          0.339916            0.249937
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
# BBY                                             0.215454
# TSLA                                            0.215454
# TWTR                                            0.215454
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
# BBY                                        0.310264  0.119981  0.387474
# TSLA                                       0.310264  0.119981  0.387474
# TWTR                                       0.310264  0.119981  0.387474
#
#                               S&P 500       BBY      TSLA      TWTR
# SOROS FUND MANAGEMENT LLC    0.837864  0.339916  0.339916  0.339916
# PAULSON & CO.INC.            0.669732  0.249937  0.249937  0.249937
# TIGER GLOBAL MANAGEMENT LLC  0.623946  0.215454  0.215454  0.215454
# BERKSHIRE HATHAWAY INC       0.751371  0.310264  0.310264  0.310264
# Algo 1                       0.279494  0.119981  0.119981  0.119981
# Algo 2                       0.858764  0.387474  0.387474  0.387474
# S&P 500                      1.000000  0.372756  0.372756  0.372756
# BBY                          0.372756  1.000000  1.000000  1.000000
# TSLA                         0.372756  1.000000  1.000000  1.000000
# TWTR                         0.372756  1.000000  1.000000  1.000000

# %%
# Beta

# %%
# Calculate Covariance for Bestbuy vs S&P 500

# %%
covariance = portfolio_df['BBY'].cov(sp500_returns_df['S&P 500'])
covariance
# Out:
# 6.8631695909824e-05

# %%
# Calculate Variance for Bestbuy

# %%
variance = portfolio_df['BBY'].var()
variance
# Out:
# 0.0006266370272030242

# %%
BBY_Roll = joined_df['BBY'].rolling(window=21).cov(sp500_returns_df['S&P 500'])/sp500_returns_df['S&P 500'].rolling(window=21).var()
BBY_Roll.dropna(inplace=True)
BBY_Roll.plot(figsize=(20, 10), title='Bestbuy Beta')
